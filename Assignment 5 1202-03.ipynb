# %%
#Importing the Datasets

(filename): ('/Users/abhishekraj/Desktop/Noopa Jagdish Assignment 5/Assignment#5')

# %%
#Importing Libraries

import glob
import numpy 
import matplotlib
import matplotlib.pyplot

# %%
#Visualizing Functions for Average, Max & Min

import sys
def visualize(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')

    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)
    

    axes1.set_ylabel('average')
    axes1.set_xlabel('Feature#')
    axes1.plot(numpy.mean(data, axis=0))
    
    axes2.set_ylabel('max')
    axes2.set_xlabel('Feature#')
    
    axes3.set_ylabel('min')
    axes3.set_xlabel('Feature#')
    
    axes2.plot(numpy.max(data, axis=0))
    axes3.plot(numpy.min(data, axis=0))    
    
    fig.tight_layout()
    matplotlib.pyplot.show()

# %%
# Defining the Identity & Displaying Charts for all 3

def identify_issues(filename):

    data=numpy.loadtxt(fname=filename,delimiter=',')
    if numpy.max(data,axis=0)[0] == 0 and numpy.max(data,axis=0)[20] == 20:
        print('I doubt the integrity of the dataset')
    elif numpy.sum(numpy.min(data,axis=0)) ==0:
        print('why is this hapening?')
    else:
        print('dataset looks good')

datasets = sys.argv[1]

# %%
# Importing sys

import sys

# Visualizing and Identifying issues of datasets
dataset = sorted(glob.glob('data*.csv'))

for datasets in dataset[:4]:
    print(datasets)
    visualize(datasets)
    identify_issues(datasets)
# Out:
# data-01.csv
# I doubt the integrity of the dataset
# data-02.csv
# dataset looks good
# data-03.csv
# why is this hapening?
# data-04.csv
# I doubt the integrity of the dataset
